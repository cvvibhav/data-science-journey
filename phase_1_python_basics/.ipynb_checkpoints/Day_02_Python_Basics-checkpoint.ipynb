# %%
#this is my first set of code
print("hello,world")
print("i'm starting my Data Science Journey")
# Out:
# hello,world
# i'm starting my Data Science Journey

# %%
#storing some variables
my_name = "Vibhav" #string
my_age = 22 #integer
my_coding_skill = 0.1 #float

#print these
print(f"my name is {my_name}.")
print(f"my age is {my_age}.")
print(f"my coding skill is {my_coding_skill}.")
# Out:
# my name is Vibhav.
# my age is 22.
# my coding skill is 0.1.

# %%
# type() is a fn that says what type of data is stored as variable

print(type(my_name))
print(type(my_age))
print(type(my_coding_skill))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
